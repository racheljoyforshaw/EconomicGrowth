# %% [markdown]
# # pandas: powerful Python data analysis toolkit
#
# **Date**: Aug 01, 2019 **Version**: 0.25.0+83.g516d7120f.dirty
#
# **Download documentation**: [PDF Version](pandas.pdf) | [Zipped HTML](pandas.zip)
#
# **Useful links**:
# [Binary Installers](https://pypi.org/project/pandas) |
# [Source Repository](https://github.com/pandas-dev/pandas) |
# [Issues & Ideas](https://github.com/pandas-dev/pandas/issues) |
# [Q&A Support](https://stackoverflow.com/questions/tagged/pandas) |
# [Mailing List](https://groups.google.com/forum/#!forum/pydata)
#
# [`pandas`](#module-pandas) is an open source, BSD-licensed library providing high-performance,
# easy-to-use data structures and data analysis tools for the [Python](https://www.python.org/)
# programming language.
#
# See the overview for more detail about what’s in the library.
#
# - [What’s new in 0.25.0 (July 18, 2019)](whatsnew/v0.25.0)
# - [Installation](install.ipynb)
# - [Getting started](getting_started/index.ipynb)
#   - [Package overview](getting_started/overview.ipynb)
#   - [10 minutes to pandas](getting_started/10min.ipynb)
#   - [Essential basic functionality](getting_started/basics.ipynb)
#   - [Intro to data structures](getting_started/dsintro.ipynb)
#   - [Comparison with other tools](getting_started/comparison/index.ipynb)
#   - [Tutorials](getting_started/tutorials.ipynb)
# - [User Guide](user_guide/index.ipynb)
#   - [IO tools (text, CSV, HDF5, …)](user_guide/io.ipynb)
#   - [Indexing and selecting data](user_guide/indexing.ipynb)
#   - [MultiIndex / advanced indexing](user_guide/advanced.ipynb)
#   - [Merge, join, and concatenate](user_guide/merging.ipynb)
#   - [Reshaping and pivot tables](user_guide/reshaping.ipynb)
#   - [Working with text data](user_guide/text.ipynb)
#   - [Working with missing data](user_guide/missing_data.ipynb)
#   - [Categorical data](user_guide/categorical.ipynb)
#   - [Nullable integer data type](user_guide/integer_na.ipynb)
#   - [Visualization](user_guide/visualization.ipynb)
#   - [Computational tools](user_guide/computation.ipynb)
#   - [Group By: split-apply-combine](user_guide/groupby.ipynb)
#   - [Time series / date functionality](user_guide/timeseries.ipynb)
#   - [Time deltas](user_guide/timedeltas.ipynb)
#   - [Styling](user_guide/style.ipynb)
#   - [Options and settings](user_guide/options.ipynb)
#   - [Enhancing performance](user_guide/enhancingperf.ipynb)
#   - [Sparse data structures](user_guide/sparse.ipynb)
#   - [Frequently Asked Questions (FAQ)](user_guide/gotchas.ipynb)
#   - [Cookbook](user_guide/cookbook.ipynb)
# - [Pandas ecosystem](ecosystem.ipynb)
# - [The Python Language Reference](https://docs.python.org/3/reference/index.html)
#   - reference/io
#   - reference/general_functions
#   - reference/series
#   - reference/frame
#   - [Array objects](https://docs.scipy.org/doc/numpy/reference/arrays.html)
#   - reference/panel
#   - reference/indexing
#   - reference/offset_frequency
#   - reference/window
#   - reference/groupby
#   - reference/resampling
#   - reference/style
#   - reference/plotting
#   - reference/general_utility_functions
#   - reference/extensions
# - [Development](development/index.ipynb)
#   - [Contributing to pandas](development/contributing.ipynb)
#   - [Internals](development/internals.ipynb)
#   - [Extending pandas](development/extending.ipynb)
#   - [Developer](development/developer.ipynb)
# - [Release Notes](whatsnew/index.ipynb)
